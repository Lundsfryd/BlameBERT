# %% [markdown]
# # Reformatting from label studio output to jsonl file. Followed by stats on inter-annotater agreement and more

# %%
#import modules


from pathlib import Path
import os

import importlib
import json_formatting

importlib.reload(json_formatting)

from json_formatting import Formatter

# %% [markdown]
# ## Convert from json format to jsonl

# %%
# set paths to each of the annotaters output paths

markus_label_studio = Path(os.path.join("..",
                           "..",
                           "raw_data",
                           "training",
                           "validation",
                           "label_studio",
                           "test_markus_gold_annotated.json"))

rune_label_studio = Path(os.path.join("..",
                           "..",
                           "raw_data",
                           "training",
                           "validation",
                           "label_studio",
                           "test_rune_gold_annotated.json"))

markus_LS_jsonl = Path(os.path.join("..",
                           "..",
                           "raw_data",
                           "training",
                           "validation",
                           "label_studio",
                           "test_markus_gold_annotated.jsonl"))

rune_LS_jsonl = Path(os.path.join("..",
                           "..",
                           "raw_data",
                           "training",
                           "validation",
                           "label_studio",
                           "test_rune_gold_annotated.jsonl"))

#set path to save merged by inter annotater agreeement
final_validation_outpath = Path(os.path.join("..",
                           "..",
                           "raw_data",
                           "training",
                           "validation",
                           "annotated_validation_set",
                           "test_validation_set.jsonl"))

# %% [markdown]
# ### Reformat from json to jsonl

# %%
json_input_files = [markus_label_studio, rune_label_studio]
jsonl_output_files = [markus_LS_jsonl, rune_LS_jsonl]

FM = Formatter()

for inp, oup in zip(json_input_files, jsonl_output_files):

    FM.json_to_jsonl(inp,oup)

# %% [markdown]
# ### Only keep sentences with agreement between annotaters for final validation. Also compute statistics

# %%
FM.compare_LS_files(markus_LS_jsonl, 
                    rune_LS_jsonl, 
                    output_file = final_validation_outpath)
# Out:
# ==================================================
# INTER-ANNOTATOR AGREEMENT REPORT
# ==================================================
#
# Aligned sentence pairs : 6
# Overall agreed pairs   : 6  (100.0%)
# Cohen's κ              : 1.000
#
#   BLAME  (label=1)
#     Both annotated      : 3
#     Only annotator 1    : 0
#     Only annotator 2    : 0
#     Agreement %         : 100.0%  (agreed / union = 3/3)
#
#   NO BLAME (label=0)
#     Both annotated      : 3
#     Only annotator 1    : 0
#     Only annotator 2    : 0
#     Agreement %         : 100.0%  (agreed / union = 3/3)
# ==================================================
#
# Agreed annotations written to: ../../raw_data/training/validation/annotated_validation_set/test_validation_set.jsonl
# {'kappa': 1.0,
#  'n_total': 6,
#  'n_agree': 6,
#  'overall_agreement_pct': 1.0,
#  'blame': {'both_annotated': 3,
#   'only_annotator_1': 0,
#   'only_annotator_2': 0,
#   'union': 3,
#   'agreement_pct': 1.0,
#   'joint_rate': 0.5},
#  'no_blame': {'both_annotated': 3,
#   'only_annotator_1': 0,
#   'only_annotator_2': 0,
#   'union': 3,
#   'agreement_pct': 1.0,
#   'joint_rate': 0.5}}
