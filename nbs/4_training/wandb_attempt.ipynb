# %%
import sys
from pathlib import Path

sys.path.append(str(Path("../../src").resolve()))

import importlib
import wandb_setup

# Reload the module
importlib.reload(wandb_setup)

# Then use the function
from wandb_setup import build_trajectory_plot_from_csv

# %%
path = Path("C:/Users/marku/Downloads/wandb_export_2026-03-17T14_05_57.227+01_00.csv")
outpath = Path("C:/Users/marku/Downloads/wandb_export_2026-03-17T14_05_57.227+01_00.html")
build_trajectory_plot_from_csv(path, outpath)
# Out:
# Plot saved to C:\Users\marku\Downloads\wandb_export_2026-03-17T14_05_57.227+01_00.html
